# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: getorg in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (0.3.1)
# Requirement already satisfied: PyYAML in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (2.9.0)
# Requirement already satisfied: retrying in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (2.32.5)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.12.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (2.6.3)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (46.0.6)
# Requirement already satisfied: cffi>=2.0.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.0.0)
# Requirement already satisfied: pycparser in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.2.25)
# Downloading python_frontmatter-1.1.0-py3-none-any.whl (9.8 kB)
# Installing collected packages: python-frontmatter
# Successfully installed python-frontmatter-1.1.0
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# High Yielding Multi-Stress Tolerant Rice Breeding Line Development from Single Cross PSB Rc14 x PSB Rc68<br />Federation of Crop Science Societies of the Philippines (FCSSP) Scientific Conference; Iloilo City, Philippines Iloilo City, Western Visayas, 5000, Philippines
# Comparative Genomic Analysis Reveals Hidden Genetic Variation for Heading Date in Weedy Rice<br />ASA-CSSA-SSA Annual International Meeting; Baltimore, Maryland, USA Baltimore, Maryland, United States
# Single Nucleotide Polymorphism (SNPs) and Its Application in Plant Breeding<br />Department of Biological Sciences, Central Luzon State University; Science City of Muñoz, Nueva Ecija, Philippines Muñoz, Nueva Ecija, Central Luzon, 3120, Philippines
# UAV-Derived Information and Genomic Data Integration for Improved Grain Yield Predictions in Soft Winter Wheat<br />Texas A&M Plant Breeding Symposium; College Station, Texas, USA College Station, Brazos County, Texas, United States
# Discriminating Nitrogen Responses and Biofuel Cropping Systems using Pleiades-Neo Satellite Imagery<br />North American Plant Phenotyping Network (NAPPN) Annual Conference; East Lansing, MI, USA East Lansing, Ingham County, Michigan, United States
# Phenomics in Soft Winter Wheat Breeding: Evaluating and Predicting Fusarium Head Blight Resistance and Grain Yield<br />Plant Breeding, Genetics, and Biotechnology Research Retreat, Michigan State University; East Lansing, Michigan, USA East Lansing, Ingham County, Michigan, United States
# Ensembles of Genomic and Hyperspectral Imaging-Based Predictions Enable Selection for Reduced Deoxynivalenol Content in Wheat Grains<br />National US Wheat and Barley Scab Initiative (USWBSI) Forum; Austin, Texas, USA Austin, Travis County, Texas, United States
# Exploring Phenomic and Genomic Data Integration in Predicting and Breeding for Economically Important Traits in Soft Winter Wheat<br />American Society of Plant Biologists Annual Meeting; Milwaukee, WI, USA Milwaukee, Milwaukee County, Wisconsin, United States
# Infrared Thermal Imaging-Based Detection and Selection for Fusarium Head Blight Resistance in Wheat<br />ASA-CSSA-SSA Annual International Meeting; Baltimore, Maryland, USA Baltimore, Maryland, United States
# Phenomics and its Application in Accelerating Genetic Gain<br />Life-Long Learning Webinar Series, Philippine Rice Research Institute; Philippines (via Zoom) None
# Infrared Thermal Imaging-Based Selection and Genome Wide Association for Fusarium Head Blight Resistance in Soft Winter Wheat<br />National US Wheat and Barley Scab Initiative (USWBSI) Forum; National Association of Plant Breeders (NAPB) Annual Meeting; Cincinnati, Ohio, USA; Greenville, South Carolina, USA None
# QTL-Seq Based Identification of Genomic Regions and Candidate Genes for Nitrogen Uptake in Rice<br />ASA-CSSA-SSA Annual International Meeting; Salt Lake City, Utah, USA Salt Lake City, Salt Lake County, Utah, United States
# Genome Wide Association Mapping of Genomic Regions Associated with Deoxynivalenol Concentration in Wheat using Spectral Reflectance Values<br />Plant and Animal Genome (PAG) Conference; San Diego, CA, USA San Diego, San Diego County, California, United States
# Hyperspectral Imaging-Based Phenomic Prediction and Selection for Deoxynivalenol Accumulation in Soft Winter Wheat<br />North American Plant Phenotyping Network (NAPPN) Annual Conference; Plant and Animal Genome (PAG 31) Conference; ASA-CSSA-SSA Annual International Meeting; West Lafayette, Indiana, USA; San Diego, California, USA; St. Louis, Missouri, USA None
# Plant Breeding and Biotechnology: As a Career, As a Science<br />National Biotechnology Week Celebration, Crop Biotechnology Center, Philippine Rice Research Institute; Philippines Philippines
# Integration of Hyperspectral Imaging for Genome Wide Association of Deoxynivalenol Accumulation in Soft Winter Wheat<br />ASA-CSSA-SSA Annual International Meeting; St. Louis, Missouri, USA Saint Louis, Missouri, United States
# UAV-Guided Genetic Dissection and Genomic Prediction of Grain Yield in Soft Winter Wheat<br />Plant and Animal Genome (PAG 32) Conference; San Diego, California, USA San Diego, San Diego County, California, United States
# High Throughput Deoxynivalenol Concentration Detection and Prediction in Fusarium-Damaged Wheat Kernels using Handheld Hyperspectral Imaging Platform<br />National US Wheat and Barley Scab Initiative (USWBSI) Forum; Tampa Bay, Florida, USA Tampa Bay, Hillsborough County, Florida, United States
# Developing Submergence Tolerant Rice for Flash Flood-Prone Areas: Status and Prospects<br />National Rice R4D Conference; PhilRice – CES, Science City of Muñoz, Nueva Ecija, Philippines None
# Writing Research Paper and Submission for Publication<br />Polytechnic University of the Philippines (PUP) Mycology Laboratory; Sta. Mesa, Manila, Philippines AKAP SA BATA NG MGA GURO-KALINGA PHILIPPINES, INC., Kalinga Street, Santa Mesa, Sixth District, Manila, Capital District, Metro Manila, 1016, Philippines
# An unhandled exception occurred while processing input San Diego, California, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Michigan, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Philippines (via Zoom) with message Non-successful status code 429

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
